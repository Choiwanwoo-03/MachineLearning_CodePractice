# %% [markdown]
# # 선문대학교
# # 컴퓨터공학부

# %% [markdown]
# ## Matplotlib 라이브러리 실습

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2], [2, 4])
plt.show()

# %%
y = [2, 3, 4, 5]
plt.plot(y)
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

plt.xlabel("number")
plt.ylabel("square")

plt.show()
