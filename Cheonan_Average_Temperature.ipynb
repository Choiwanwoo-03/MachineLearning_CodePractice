# %% [markdown]
# # 선문대학교 컴퓨터공학부
# # 2022243101 최완우

# %% [markdown]
# ### 사는 지역 : 충청남도 천안시
# ### 1. 파일이름 : 'Cheonan_Temp.csv'

# %% [markdown]
# ### 1.1 데이터 읽어오기

# %%
import pandas as pd

data = pd.read_csv('Cheonan_Temp.csv', encoding = 'cp949')
data
# Out:
#                날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0    \t2025-01-01  232.0      0.4     -6.1      9.1
# 1    \t2025-01-02  232.0     -0.6     -5.6      6.7
# 2    \t2025-01-03  232.0     -1.7     -7.1      3.3
# 3    \t2025-01-04  232.0     -1.6     -7.4      5.6
# 4    \t2025-01-05  232.0      0.6     -5.6      3.5
# ..            ...    ...      ...      ...      ...
# 361  \t2025-12-28  232.0      2.2     -0.9      7.3
# 362  \t2025-12-29  232.0      3.4     -1.3      9.6
# 363  \t2025-12-30  232.0     -0.6     -4.6      4.2
# 364  \t2025-12-31  232.0     -3.9     -7.1     -1.3
# 365            \t    NaN      NaN      NaN      NaN
#
# [366 rows x 5 columns]

# %%
# 날짜 앞에 \t 없애기
data['날짜'] = data['날짜'].str.replace('\t', '')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       366 non-null    str
#  1   지점       365 non-null    float64
#  2   평균기온(℃)  364 non-null    float64
#  3   최저기온(℃)  365 non-null    float64
#  4   최고기온(℃)  365 non-null    float64
# dtypes: float64(4), str(1)
# memory usage: 14.4 KB

# %% [markdown]
# ### 0   날짜        문자열
# ### 1   지점        소수
# ### 2   평균기온(℃) 소수
# ### 3   최저기온(℃) 소수
# ### 4   최고기온(℃) 소수

# %%
# 날짜 컬럼의 string 타입을 날짜형식(datetime)으로 변환하기
data['날짜'] = pd.to_datetime(data['날짜'])
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       365 non-null    datetime64[us]
#  1   지점       365 non-null    float64
#  2   평균기온(℃)  364 non-null    float64
#  3   최저기온(℃)  365 non-null    float64
#  4   최고기온(℃)  365 non-null    float64
# dtypes: datetime64[us](1), float64(4)
# memory usage: 14.4 KB

# %%
data
# Out:
#             날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0   2025-01-01  232.0      0.4     -6.1      9.1
# 1   2025-01-02  232.0     -0.6     -5.6      6.7
# 2   2025-01-03  232.0     -1.7     -7.1      3.3
# 3   2025-01-04  232.0     -1.6     -7.4      5.6
# 4   2025-01-05  232.0      0.6     -5.6      3.5
# ..         ...    ...      ...      ...      ...
# 361 2025-12-28  232.0      2.2     -0.9      7.3
# 362 2025-12-29  232.0      3.4     -1.3      9.6
# 363 2025-12-30  232.0     -0.6     -4.6      4.2
# 364 2025-12-31  232.0     -3.9     -7.1     -1.3
# 365        NaT    NaN      NaN      NaN      NaN
#
# [366 rows x 5 columns]

# %%
# 최고기온 날짜와 함께 저장하기
Max_Temp = data.iloc[:, [0, 4]]
Max_Temp
# Out:
#             날짜  최고기온(℃)
# 0   2025-01-01      9.1
# 1   2025-01-02      6.7
# 2   2025-01-03      3.3
# 3   2025-01-04      5.6
# 4   2025-01-05      3.5
# ..         ...      ...
# 361 2025-12-28      7.3
# 362 2025-12-29      9.6
# 363 2025-12-30      4.2
# 364 2025-12-31     -1.3
# 365        NaT      NaN
#
# [366 rows x 2 columns]

# %%
# 최저기온 날짜와 함께 저장하기
Min_Temp = data.iloc[:, [0, 3]]
Min_Temp
# Out:
#             날짜  최저기온(℃)
# 0   2025-01-01     -6.1
# 1   2025-01-02     -5.6
# 2   2025-01-03     -7.1
# 3   2025-01-04     -7.4
# 4   2025-01-05     -5.6
# ..         ...      ...
# 361 2025-12-28     -0.9
# 362 2025-12-29     -1.3
# 363 2025-12-30     -4.6
# 364 2025-12-31     -7.1
# 365        NaT      NaN
#
# [366 rows x 2 columns]

# %% [markdown]
# ### 1.2 데이터 시각화 하기

# %%
import matplotlib.pyplot as plt

plt.plot(Max_Temp['날짜'], Max_Temp['최고기온(℃)'])
plt.xticks(rotation = 45)
plt.title('2025년 최고기온 그래프')

plt.show()

# %%
# 내가 태어난 달에 해당하는 최고기온 데이터만 추출하기
month_result = Max_Temp[Max_Temp['날짜'].dt.month == 9]
month_result
# Out:
#             날짜  최고기온(℃)
# 243 2025-09-01     31.2
# 244 2025-09-02     28.9
# 245 2025-09-03     32.1
# 246 2025-09-04     29.8
# 247 2025-09-05     32.0
# 248 2025-09-06     31.8
# 249 2025-09-07     27.8
# 250 2025-09-08     25.4
# 251 2025-09-09     23.8
# 252 2025-09-10     29.0
# 253 2025-09-11     29.9
# 254 2025-09-12     24.8
# 255 2025-09-13     26.1
# 256 2025-09-14     28.3
# 257 2025-09-15     28.8
# 258 2025-09-16     30.5
# 259 2025-09-17     25.5
# 260 2025-09-18     25.3
# 261 2025-09-19     21.6
# 262 2025-09-20     23.1
# 263 2025-09-21     25.8
# 264 2025-09-22     24.5
# 265 2025-09-23     26.1
# 266 2025-09-24     25.5
# 267 2025-09-25     24.5
# 268 2025-09-26     25.7
# 269 2025-09-27     27.2
# 270 2025-09-28     21.2
# 271 2025-09-29     24.4
# 272 2025-09-30     23.5

# %%
plt.bar(month_result['날짜'], month_result['최고기온(℃)'])
plt.xticks(rotation = 45)
plt.title('9월달 최고기온 그래프')

plt.show()

# %%
# 내 생일에 해당하는 최저/최고 기온만 추출
birthday_result = Max_Temp[(Max_Temp['날짜'].dt.month == 9) & (Max_Temp['날짜'].dt.day == 29)]
birthday_result

birthday_result2 = Min_Temp[(Min_Temp['날짜'].dt.month == 9) & (Min_Temp['날짜'].dt.day == 29)]
birthday_result2

print(birthday_result)
print(birthday_result2)
# Out:
#             날짜  최고기온(℃)
# 271 2025-09-29     24.4
#             날짜  최저기온(℃)
# 271 2025-09-29     14.8

# %%
import seaborn as sns

# 1. 전체 데이터로 배경 등고선 그리기
# 최고/최저 기온에 NaN값 제거
cleand_data = data.dropna(subset=['최저기온(℃)', '최고기온(℃)'])

plt.figure(figsize=(10, 8))

# 천안시 전체 기온의 밀도 분포
sns.kdeplot(
    x=cleand_data['최저기온(℃)'], 
    y=cleand_data['최고기온(℃)'], 
    fill=True, 
    cmap='viridis',
    alpha=0.8,
    thresh=0.05
)

# 2. 단 생일 데이터(birthday_result2)를 그 위에 별표로 찍기
plt.scatter(
    birthday_result2['최저기온(℃)'], 
    birthday_result['최고기온(℃)'], 
    color='red',    
    marker='*',   
    s=300,    
    label='My Birthday',
    zorder=5 
)

plt.title('천안시 기온 분포 & 나의 생일 최고/최저기온')
plt.xlabel('최저기온(℃)')
plt.ylabel('최고기온(℃)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# ### 3. 그 외 시각화 연습

# %%
# 6월과 12월의 최고기온을 fill_between으로 시각화하기
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False 

data = pd.read_csv('Cheonan_Temp.csv', encoding='cp949')
data['날짜'] = data['날짜'].str.replace('\t', '')
data['날짜'] = pd.to_datetime(data['날짜'])

cleand_data = data.dropna(subset=['최저기온(℃)', '최고기온(℃)'])
Max_Temp = cleand_data.iloc[:, [0, 4]]

june = Max_Temp[Max_Temp['날짜'].dt.month == 6]
dec = Max_Temp[Max_Temp['날짜'].dt.month == 12]

tempmin_june = june['최고기온(℃)'].min()
tempmin_dec = dec['최고기온(℃)'].min()

fig, ((ax2, ax4)) = plt.subplots(1, 2, figsize = (12, 8))

ax2.fill_between(june['날짜'], tempmin_june, june['최고기온(℃)'], alpha = 0.7, color = 'tomato')
ax2.grid(True)
ax2.label_outer()
ax2.set_title('6월 최고기온')
ax2.tick_params(axis = 'x', rotation = 45)

ax4.fill_between(dec['날짜'], tempmin_dec, dec['최고기온(℃)'], alpha = 0.7, color = 'steelblue')
ax4.grid(True)
ax4.label_outer()
ax4.set_title('12월 최고기온')
ax4.tick_params(axis = 'x', rotation = 45)

fig.suptitle('천안시 6월, 12월 최고기온')
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
# 3월과 9월의 최저기온을 violinplot으로 시각화하기
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

import pandas as pd
import seaborn as sns

sns.set_theme(style='whitegrid')

data = pd.read_csv('Cheonan_Temp.csv', encoding='cp949')
data['날짜'] = data['날짜'].str.replace('\t', '')
data['날짜'] = pd.to_datetime(data['날짜'])

cleand_data = data.dropna(subset=['최저기온(℃)', '최고기온(℃)'])
Min_Temp = cleand_data.iloc[:, [0, 3]]

march = Min_Temp[Min_Temp['날짜'].dt.month == 3]
sep = Min_Temp[Min_Temp['날짜'].dt.month == 9]

march = march.copy()
march['월'] = '3월'

sep = sep.copy()
sep['월'] = '9월'

df_plot = pd.concat([march, sep])

f, ax = plt.subplots(figsize=(8, 6))

sns.violinplot(data=df_plot, x='월', y='최저기온(℃)',
               bw_adjust=0.5, cut=1, linewidth=1, palette='Set3')

ax.set_title('천안시 3월 vs 9월 최저기온 분포')
sns.despine(left=True, bottom=True)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\최완우\AppData\Local\Temp\ipykernel_8524\1460501736.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_plot, x='월', y='최저기온(℃)',
# C:\Users\최완우\AppData\Local\Temp\ipykernel_8524\1460501736.py:40: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\최완우\AppData\Local\Temp\ipykernel_8524\1460501736.py:40: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\최완우\AppData\Local\Temp\ipykernel_8524\1460501736.py:40: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\최완우\AppData\Local\Temp\ipykernel_8524\1460501736.py:40: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) Arial.
#   plt.tight_layout()
# ...
