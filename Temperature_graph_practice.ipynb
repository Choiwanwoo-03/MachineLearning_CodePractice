# %% [markdown]
# # 선문대학교 컴퓨터공학부
# # 2022243101 최완우

# %% [markdown]
# ### [실습]_내_생일의_기온_변화를_그래프로_그리기

# %%
import pandas as pd

data = pd.read_csv('3.1.2.temp.csv', encoding = 'cp949')
data
# Out:
#                  날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      \t1983-01-01  232.0     -2.3     -7.0      4.4
# 1      \t1983-01-02  232.0     -1.4     -5.7      4.4
# 2      \t1983-01-03  232.0     -2.2     -7.5      5.2
# 3      \t1983-01-04  232.0     -1.5     -6.8      4.2
# 4      \t1983-01-05  232.0      0.9     -2.3      4.0
# ...             ...    ...      ...      ...      ...
# 15399  \t2025-02-28  232.0      6.7      1.5     14.0
# 15400  \t2025-03-01  232.0      5.4     -1.5     10.6
# 15401  \t2025-03-02  232.0      8.7      3.5     13.5
# 15402  \t2025-03-03  232.0      2.9      1.0      5.3
# 15403            \t    NaN      NaN      NaN      NaN
#
# [15404 rows x 5 columns]

# %%
data['날짜'] = data['날짜'].str.replace('\t', '')
data
# Out:
#                날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      1983-01-01  232.0     -2.3     -7.0      4.4
# 1      1983-01-02  232.0     -1.4     -5.7      4.4
# 2      1983-01-03  232.0     -2.2     -7.5      5.2
# 3      1983-01-04  232.0     -1.5     -6.8      4.2
# 4      1983-01-05  232.0      0.9     -2.3      4.0
# ...           ...    ...      ...      ...      ...
# 15399  2025-02-28  232.0      6.7      1.5     14.0
# 15400  2025-03-01  232.0      5.4     -1.5     10.6
# 15401  2025-03-02  232.0      8.7      3.5     13.5
# 15402  2025-03-03  232.0      2.9      1.0      5.3
# 15403                NaN      NaN      NaN      NaN
#
# [15404 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15404 entries, 0 to 15403
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       15404 non-null  str
#  1   지점       15403 non-null  float64
#  2   평균기온(℃)  15400 non-null  float64
#  3   최저기온(℃)  15402 non-null  float64
#  4   최고기온(℃)  15403 non-null  float64
# dtypes: float64(4), str(1)
# memory usage: 601.8 KB

# %%
data['날짜'] = pd.to_datetime(data['날짜'])
data.info
# Out:
# <bound method DataFrame.info of               날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0     1983-01-01  232.0     -2.3     -7.0      4.4
# 1     1983-01-02  232.0     -1.4     -5.7      4.4
# 2     1983-01-03  232.0     -2.2     -7.5      5.2
# 3     1983-01-04  232.0     -1.5     -6.8      4.2
# 4     1983-01-05  232.0      0.9     -2.3      4.0
# ...          ...    ...      ...      ...      ...
# 15399 2025-02-28  232.0      6.7      1.5     14.0
# 15400 2025-03-01  232.0      5.4     -1.5     10.6
# 15401 2025-03-02  232.0      8.7      3.5     13.5
# 15402 2025-03-03  232.0      2.9      1.0      5.3
# 15403        NaT    NaN      NaN      NaN      NaN
#
# [15404 rows x 5 columns]>

# %%
result = data.iloc[:, [0, 4]]
result
# Out:
#               날짜  최고기온(℃)
# 0     1983-01-01      4.4
# 1     1983-01-02      4.4
# 2     1983-01-03      5.2
# 3     1983-01-04      4.2
# 4     1983-01-05      4.0
# ...          ...      ...
# 15399 2025-02-28     14.0
# 15400 2025-03-01     10.6
# 15401 2025-03-02     13.5
# 15402 2025-03-03      5.3
# 15403        NaT      NaN
#
# [15404 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(result['최고기온(℃)'])

# %%
month_result = result[result['날짜'].dt.month == 8]
month_result
# Out:
#               날짜  최고기온(℃)
# 212   1983-08-01     34.8
# 213   1983-08-02     34.7
# 214   1983-08-03     35.0
# 215   1983-08-04     34.7
# 216   1983-08-05     34.7
# ...          ...      ...
# 15214 2024-08-27     26.9
# 15215 2024-08-28     31.7
# 15216 2024-08-29     32.4
# 15217 2024-08-30     32.3
# 15218 2024-08-31     30.8
#
# [1302 rows x 2 columns]

# %%
plt.plot(month_result['최고기온(℃)'])

# %%
birthday_result = result[(result['날짜'].dt.month == 8) & (result['날짜'].dt.day == 16)]
birthday_result
# Out:
#               날짜  최고기온(℃)
# 227   1983-08-16     32.4
# 593   1984-08-16     28.8
# 958   1985-08-16     29.6
# 1323  1986-08-16     30.6
# 1688  1987-08-16     27.0
# 2054  1988-08-16     32.5
# 2419  1989-08-16     30.8
# 2784  1990-08-16     29.6
# 3149  1991-08-16     32.8
# 3515  1992-08-16     29.4
# 3880  1993-08-16     21.8
# 4245  1994-08-16     34.1
# 4610  1995-08-16     32.3
# 4976  1996-08-16     32.6
# 5341  1997-08-16     31.5
# 5706  1998-08-16     27.9
# 6071  1999-08-16     30.9
# 6437  2000-08-16     33.1
# 6802  2001-08-16     35.7
# 7167  2002-08-16     25.7
# 7532  2003-08-16     22.7
# 7898  2004-08-16     29.7
# 8263  2005-08-16     32.7
# 8628  2006-08-16     33.0
# 8993  2007-08-16     32.5
# 9359  2008-08-16     24.0
# 9724  2009-08-16     31.8
# 10089 2010-08-16     25.9
# 10454 2011-08-16     30.4
# 10820 2012-08-16     27.8
# 11185 2013-08-16     33.6
# 11550 2014-08-16     31.2
# 11915 2015-08-16     29.6
# 12281 2016-08-16     33.9
# 12646 2017-08-16     27.0
# 13011 2018-08-16     33.9
# 13376 2019-08-16     28.3
# 13742 2020-08-16     31.8
# 14107 2021-08-16     28.9
# 14472 2022-08-16     30.3
# 14837 2023-08-16     31.4
# 15203 2024-08-16     33.6

# %%
plt.plot(birthday_result['최고기온(℃)'])

# %%
birthday_result2 = data[(data['날짜'].dt.month == 8) & (data['날짜'].dt.day == 16)]
birthday_result2
# Out:
#               날짜     지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 227   1983-08-16  232.0     26.1     18.7     32.4
# 593   1984-08-16  232.0     23.6     17.9     28.8
# 958   1985-08-16  232.0     23.9     19.9     29.6
# 1323  1986-08-16  232.0     25.2     22.7     30.6
# 1688  1987-08-16  232.0     24.9     23.0     27.0
# 2054  1988-08-16  232.0     27.3     23.1     32.5
# 2419  1989-08-16  232.0     24.5     16.9     30.8
# 2784  1990-08-16  232.0     23.7     20.2     29.6
# 3149  1991-08-16  232.0     26.2     20.3     32.8
# 3515  1992-08-16  232.0     24.3     20.8     29.4
# 3880  1993-08-16  232.0     19.5     17.6     21.8
# 4245  1994-08-16  232.0     29.4     23.9     34.1
# 4610  1995-08-16  232.0     26.6     22.0     32.3
# 4976  1996-08-16  232.0     25.2     19.5     32.6
# 5341  1997-08-16  232.0     25.1     19.9     31.5
# 5706  1998-08-16  232.0     24.3     22.2     27.9
# 6071  1999-08-16  232.0     25.2     19.1     30.9
# 6437  2000-08-16  232.0     26.6     22.7     33.1
# 6802  2001-08-16  232.0     27.9     22.0     35.7
# 7167  2002-08-16  232.0     22.6     20.3     25.7
# 7532  2003-08-16  232.0     19.7     16.2     22.7
# 7898  2004-08-16  232.0     24.4     21.7     29.7
# 8263  2005-08-16  232.0     26.8     23.1     32.7
# 8628  2006-08-16  232.0     26.8     22.1     33.0
# 8993  2007-08-16  232.0     27.6     24.2     32.5
# 9359  2008-08-16  232.0     21.8     19.0     24.0
# 9724  2009-08-16  232.0     26.6     20.8     31.8
# 10089 2010-08-16  232.0     24.0     21.8     25.9
# 10454 2011-08-16  232.0     26.7     23.9     30.4
# 10820 2012-08-16  232.0     24.1     22.6     27.8
# 11185 2013-08-16  232.0     27.8     23.8     33.6
# 11550 2014-08-16  232.0     24.9     19.3     31.2
# 11915 2015-08-16  232.0     24.7     21.6     29.6
# 12281 2016-08-16  232.0     27.8     22.8     33.9
# 12646 2017-08-16  232.0     23.9     21.6     27.0
# 13011 2018-08-16  232.0     28.1     23.8     33.9
# 13376 2019-08-16  232.0     24.8     21.4     28.3
# 13742 2020-08-16  232.0     26.8     23.2     31.8
# 14107 2021-08-16  232.0     24.6     19.7     28.9
# 14472 2022-08-16  232.0     25.6     21.8     30.3
# 14837 2023-08-16  232.0     25.9     23.1     31.4
# 15203 2024-08-16  232.0     28.3     23.2     33.6

# %%
plt.plot(birthday_result2['최저기온(℃)'])
plt.plot(birthday_result2['최고기온(℃)'])

# %%
plt.plot(birthday_result2['날짜'], birthday_result2['최저기온(℃)'])
plt.plot(birthday_result2['날짜'], birthday_result2['최고기온(℃)'])

# %%
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = 'Malgun Gothic'  # 맑은 고딕
plt.rcParams['axes.unicode_minus'] = False

plt.plot(birthday_result2['날짜'], birthday_result2['최저기온(℃)'])
plt.plot(birthday_result2['날짜'], birthday_result2['최고기온(℃)'])
plt.title('내 생일의 기온 변화 그래프')
# Out:
# Text(0.5, 1.0, '내 생일의 기온 변화 그래프')

# %%
plt.rc('font', family = 'NanumGothic')

birthday_result2 = data[(data['날짜'].dt.month == 9) & (data['날짜'].dt.day == 29)]
birthday_result2

plt.plot(birthday_result2['날짜'], birthday_result2['최저기온(℃)'])
plt.plot(birthday_result2['날짜'], birthday_result2['최고기온(℃)'])
plt.title('내 생일의 기온 변화 그래프')
# Out:
# Text(0.5, 1.0, '내 생일의 기온 변화 그래프')
