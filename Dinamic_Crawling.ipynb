# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
wd = webdriver.Chrome()

# %%
wd.get("https://www.coffeebeankorea.com/store/store.asp")

# %%
wd.execute_script("storePop2(114)")
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 wd.execute_script("storePop2(114)")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:532, in WebDriver.execute_script(self, script, *args)
#     529 converted_args = list(args)
#     530 command = Command.W3C_EXECUTE_SCRIPT
# --> 532 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:446, in WebDriver.execute(self, driver_command, params)
#     443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
# --> 446     self.error_handler.check_response(response)
#     447     response["value"] = self._unwrap_value(response.get("value", None))
#     448     return response
#
# ...

# %%
html = wd.page_source
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 html = wd.page_source
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:561, in WebDriver.page_source(self)
#     558 @property
#     559 def page_source(self) -> str:
#     560     """Gets the source of the current page."""
# --> 561     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:446, in WebDriver.execute(self, driver_command, params)
#     443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
# --> 446     self.error_handler.check_response(response)
#     447     response["value"] = self._unwrap_value(response.get("value", None))
#     448     return response
#
# ...
