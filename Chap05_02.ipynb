# %% [markdown]
# # 선문대학교 컴퓨터공학부
# # 2022243101 최완우

# %% [markdown]
# # **4. 선형회귀와 지도학습**
# ---
# * 출판사 : 생능 출판사( http://www.booksr.co.kr/ )
# * 으뜸 머신러닝 저자 : 강영민, 박동규, 김성수
# *  소스코드 저장소 : https://github.com/dknife/ML2nd
# *  저작권 : 본 노트북 코드는 자유롭게 배포가능하지만 위의 출판사, 저서, 저자표기와 함께 배포해 주십시오.
# ---

# %% [markdown]
# ### 5.2 k-NN 알고리즘을 위한 데이터 준비

# %%
import matplotlib.pyplot as plt
import numpy

dach_length = [77, 78, 85, 83, 73, 77, 73, 80]
dach_height = [25, 28, 29, 30, 21, 22, 17, 35]

samo_length = [75, 77, 86, 86, 79, 83, 83, 88]
samo_height = [56, 57, 50, 53, 60, 53, 49, 61]

plt.scatter(dach_length, dach_height, c = 'red', label = 'Dachshund')
plt.scatter(samo_length, samo_height, c = 'blue', marker = '^', label = 'Samoyed')

plt.xlabel('Length')
plt.ylabel('Height')
plt.title("Dog size")
plt.legend(loc = 'upper left')

plt.show()

# %%
newdata_length = [79]
newdata_height = [35]

plt.scatter(dach_length, dach_height, c= 'red', label = 'Dachshund')
plt.scatter(samo_length, samo_height, c = 'blue', marker = '^',\
    label = 'Samoyed')
plt.scatter(newdata_length, newdata_height, s = 100, marker = 'p',\
    c = 'green', label = 'New Data')

plt.xlabel('Length')
plt.ylabel('Height')
plt.title("Dog size")
plt.legend(loc = 'upper left')
